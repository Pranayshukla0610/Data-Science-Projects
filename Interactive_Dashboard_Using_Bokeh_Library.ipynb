# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/Data-Science-Projects/blob/main/Interactive_Dashboard_Using_Bokeh_Library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from bokeh.io import output_notebook, show
from bokeh.plotting import figure
from bokeh.layouts import row, column
from bokeh.models import (
    ColumnDataSource,
    HoverTool,
    Select
)
from bokeh.models.widgets import Div
from bokeh.io import curdoc

# %%
output_notebook()

# %%
data = pd.DataFrame({
    'Month':['Jan','Feb','Mar','Apr','May','June'],
    'Sales':[120,150,170,160,180,200],
    'Profit':[10,20,30,40,50,60],
    'Region':['North','South','East','West','North','South']
})

# %%
source = ColumnDataSource(data)

# %%
p1 = figure(
    title = 'Monthly Sales',
    x_range = data['Month'],
    width = 600,
    height = 400,
    tools = 'pan,wheel_zoom,box_zoom,reset,save'
)

p1.line(
    x='Month',
    y='Sales',
    source=source,
    line_width=3
)
p1.circle(
    x='Month',
    y='Sales',
    source=source,
    color='red',
    size=10
)

hover = HoverTool(
    tooltips=[
        ('Month','@Month'),
        ('Sales','@Sales'),
        ('Profit','@Profit')
    ]
)

p1.add_tools(hover)

# %%
p2 = figure(
    title = 'Profit Analysis',
    x_range = data['Month'],
    width=600,
    height=400
)

p2.vbar(
    x = 'Month',
    top = 'Profit',
    source=source,
    width=0.5
)
total_sales = data['Sales'].sum()
total_profit = data['Profit'].sum()

kpi = Div(text=f"""
<h1>Interactive Sales Dashboard</h1>
<h3>Total Sales: {total_sales}</h3>
<h3>Total Profit: {total_profit}</h3>
""")

select = Select(
    title="Select Region",
    value="All",
    options=["All"] + list(data['Region'].unique())
)

# %%
def update(attr, old, new):

    region = select.value

    if region == "All":
        filtered = data
    else:
        filtered = data[data['Region'] == region]

    source.data = ColumnDataSource(filtered).data

select.on_change('value', update)

layout = column(
    kpi,
    select,
    row(p1, p2)
)

# %%
show(layout)
# Out:
# WARNING:bokeh.embed.util:
# You are generating standalone HTML/JS output, but trying to use real Python
# callbacks (i.e. with on_change or on_event). This combination cannot work.
#
# Only JavaScript callbacks may be used with standalone output. For more
# information on JavaScript callbacks with Bokeh, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/interaction/js_callbacks.html
#
# Alternatively, to use real Python callbacks, a Bokeh server application may
# be used. For more information on building and running Bokeh applications, see:
#
#     https://docs.bokeh.org/en/latest/docs/user_guide/server.html
#   <div id="eb26faff-6d32-4448-9155-f53c67329167" data-root-id="p1113" style="display: contents;"></div>
